# %%
from pymystem3 import Mystem
from catboost import Pool, CatBoostClassifier 
import re

mystem = Mystem()

# %%
class Tag:
    
    def __init__(self, start, length, word=None, tag=None):
        self.word = word
        self.start = start
        self.length = length
        self.tag = tag
        
    def __str__(self):
        return f'{self.word} {self.start} {self.length} {self.tag}'

# %%
def intersect(word, tag):
    return (word.start >= tag.start and word.start <= tag.start + tag.length) or \
           (tag.start >= word.start and tag.start <= word.start + word.length)

def load_labels(data):
    lines = None
    with open('labels.txt') as labels:
        lines = labels.readlines()
    labels = []
    for line, seq in zip(lines, data):
        split = iter(line.split())        
        tags = []
        while True:
            token = next(split)
            if token == 'EOL':
                break
            else:
                start = int(token)
                length = int(next(split))
                tag = next(split)
                word = seq[start:start + length]
                tags.append(Tag(start=start, length=length, tag=tag, word=word))
        
        all_words = parse_words(seq)
        for w in all_words:
            for t in tags:
                if intersect(w, t):
                    w.tag = t.tag
        
        # all_words = list(filter(lambda x: not any(map(lambda y: intersect(y, x), tags)), parse_words(seq)))
        
        labels.append(all_words)
    return labels

def load_data(file):
    with open(file) as f:
        return list(f.readlines())

separators = ['.', ',', '—', ' ', '\n', '?', '!', '"', '(', ')', '«', '»']

def parse_words(line):
    words = []
    word = []
    for i in range(len(line)):
        if line[i] not in separators:
            word.append(line[i])
        else:
            if word:
                words.append(Tag(word=''.join(word), tag=None, start=i - len(word), length=len(word)))
                word = []
    return words

# %%
def get_features(word):
    has_capital = 1 if (re.match('[А-ЯЁ]', word.word) is not None) else 0
    caps = 1 if word.word == word.word.upper() else 0
    latin = 1 if re.match('[A-Z]', word.word) else 0
    
    tag = 'NA'
    if 'analysis' in mystem.analyze(word.word)[0]:
        x = mystem.analyze(word.word)[0]['analysis']
        if x != []:
            tag = re.match('[A-Z]+', x[0]['gr'])[0]   
    
    
    return [has_capital, caps, latin, tag]

# %%
# def context_features(words):
#     if len(words) == 1:
#         return [[0, 0, 0, 'NA'] + get_features(words[0]) + [0, 0, 0, 'NA']]
    
#     d = []
#     d.append([0, 0, 0, 'NA'] + get_features(words[0]) + get_features(words[1]))
#     for i in range(1, len(words) - 1):
#         d.append(get_features(words[i-1]) + get_features(words[i]) + get_features(words[i + 1]))
#     d.append(get_features(words[-2]) + get_features(words[-1]) + [0, 0, 0, 'NA'])
#     return d

CONTEXT_SIZE = 2

def context_features(words):
    features = list(map(get_features, words))
    padding = [0, 0, 0, 'NA']
    for i in range(CONTEXT_SIZE):
        features.append(padding)
        features.insert(0, padding)
    
    d = []
    for i in range(CONTEXT_SIZE, len(features) - CONTEXT_SIZE):
        context = []
        for j in range(CONTEXT_SIZE):
            context.extend(features[i - j])
        context.extend(features[i])
#         for j in range(CONTEXT_SIZE):
#             context.extend(features[i + j])
        d.append(context)
    return d

# %%
data = load_labels(load_data('train.txt'))

train_data = []
for words in data:
    train_data.extend(context_features(words))

print(train_data[:10])
# Out:
# [[1, 0, 0, 'S', 0, 0, 0, 'NA', 1, 0, 0, 'S'], [0, 0, 0, 'S', 1, 0, 0, 'S', 0, 0, 0, 'S'], [0, 0, 0, 'S', 0, 0, 0, 'S', 0, 0, 0, 'S'], [0, 0, 0, 'CONJ', 0, 0, 0, 'S', 0, 0, 0, 'CONJ'], [0, 0, 0, 'S', 0, 0, 0, 'CONJ', 0, 0, 0, 'S'], [0, 0, 0, 'PR', 0, 0, 0, 'S', 0, 0, 0, 'PR'], [0, 0, 0, 'A', 0, 0, 0, 'PR', 0, 0, 0, 'A'], [0, 0, 0, 'CONJ', 0, 0, 0, 'A', 0, 0, 0, 'CONJ'], [0, 0, 0, 'S', 0, 0, 0, 'CONJ', 0, 0, 0, 'S'], [0, 0, 0, 'S', 0, 0, 0, 'S', 0, 0, 0, 'S']]

# %%
train_label = []
for x in data:
    for y in x:
        train_label.append(y.tag)

# %%
cat_features = [i for i in range(12)]
train_dataset = Pool(data=train_data,
                     label=train_label,
                     cat_features=cat_features)

# %%
model = CatBoostClassifier(iterations=150,
                           learning_rate=1,
                           depth=10,
                           loss_function='MultiClass',
                           task_type='GPU')

model.fit(train_dataset)
# Out:
# 0:	learn: 0.2864879	total: 27.2ms	remaining: 4.05s
# 1:	learn: 0.2382886	total: 52.9ms	remaining: 3.92s
# 2:	learn: 0.2232431	total: 79.9ms	remaining: 3.92s
# 3:	learn: 0.2175505	total: 105ms	remaining: 3.82s
# 4:	learn: 0.2149835	total: 131ms	remaining: 3.79s
# 5:	learn: 0.2137000	total: 156ms	remaining: 3.73s
# 6:	learn: 0.2127568	total: 185ms	remaining: 3.77s
# 7:	learn: 0.2121860	total: 210ms	remaining: 3.73s
# 8:	learn: 0.2118126	total: 236ms	remaining: 3.7s
# 9:	learn: 0.2112926	total: 263ms	remaining: 3.68s
# 10:	learn: 0.2108173	total: 290ms	remaining: 3.66s
# 11:	learn: 0.2102403	total: 316ms	remaining: 3.63s
# 12:	learn: 0.2095641	total: 344ms	remaining: 3.63s
# 13:	learn: 0.2092749	total: 371ms	remaining: 3.6s
# 14:	learn: 0.2089809	total: 398ms	remaining: 3.58s
# 15:	learn: 0.2088663	total: 425ms	remaining: 3.56s
# 16:	learn: 0.2085103	total: 454ms	remaining: 3.56s
# 17:	learn: 0.2083296	total: 485ms	remaining: 3.55s
# 18:	learn: 0.2081321	total: 513ms	remaining: 3.53s
# 19:	learn: 0.2079936	total: 538ms	remaining: 3.5s
# 20:	learn: 0.2076803	total: 566ms	remaining: 3.48s
# 21:	learn: 0.2073814	total: 593ms	remaining: 3.45s
# 22:	learn: 0.2072616	total: 619ms	remaining: 3.42s
# 23:	learn: 0.2070528	total: 646ms	remaining: 3.39s
# 24:	learn: 0.2069694	total: 676ms	remaining: 3.38s
# 25:	learn: 0.2068292	total: 703ms	remaining: 3.35s
# 26:	learn: 0.2065362	total: 732ms	remaining: 3.33s
# 27:	learn: 0.2063201	total: 762ms	remaining: 3.32s
# 28:	learn: 0.2061220	total: 789ms	remaining: 3.29s
# 29:	learn: 0.2059978	total: 815ms	remaining: 3.26s
# 30:	learn: 0.2056975	total: 843ms	remaining: 3.23s
# 125:	learn: 0.2013739	total: 3.68s	remaining: 702ms
# 126:	learn: 0.2013641	total: 3.71s	remaining: 672ms
# 127:	learn: 0.2013281	total: 3.74s	remaining: 642ms
# 128:	learn: 0.2013184	total: 3.76s	remaining: 613ms
# 129:	learn: 0.2013082	total: 3.79s	remaining: 583ms
# 130:	learn: 0.2012918	total: 3.82s	remaining: 554ms
# 131:	learn: 0.2012888	total: 3.84s	remaining: 524ms
# 132:	learn: 0.2012797	total: 3.87s	remaining: 495ms
# 133:	learn: 0.2012545	total: 3.9s	remaining: 466ms
# 134:	learn: 0.2012415	total: 3.92s	remaining: 436ms
# 135:	learn: 0.2012168	total: 3.95s	remaining: 407ms
# 136:	learn: 0.2012104	total: 3.98s	remaining: 378ms
# 137:	learn: 0.2012003	total: 4.01s	remaining: 349ms
# 138:	learn: 0.2011840	total: 4.03s	remaining: 319ms
# 139:	learn: 0.2011790	total: 4.07s	remaining: 290ms
# 140:	learn: 0.2011713	total: 4.1s	remaining: 262ms
# 141:	learn: 0.2011664	total: 4.13s	remaining: 233ms
# 142:	learn: 0.2011351	total: 4.17s	remaining: 204ms
# 143:	learn: 0.2011322	total: 4.2s	remaining: 175ms
# 144:	learn: 0.2011170	total: 4.24s	remaining: 146ms
# 145:	learn: 0.2010762	total: 4.27s	remaining: 117ms
# 146:	learn: 0.2010702	total: 4.3s	remaining: 87.8ms
# 147:	learn: 0.2010607	total: 4.33s	remaining: 58.5ms
# 148:	learn: 0.2010518	total: 4.36s	remaining: 29.3ms
# 149:	learn: 0.2010480	total: 4.39s	remaining: 0us

# %%
test_data = load_data('test.txt')

for line in test_data:
    words = parse_words(line)
    eval_data = context_features(words)
    classes = model.predict(eval_data)
    for cl, w in zip(classes, words):
        if cl[0] != 'None':
            print(w.start, w.length, cl[0], end=' ')
    print('EOL')
# Out:
# EOL
# EOL
# 16 7 PERSON EOL
# EOL
# EOL
# EOL
# 66 3 ORG EOL
# 56 6 PERSON 63 8 PERSON EOL
# EOL
# 26 7 ORG EOL
# EOL
# 6 15 ORG EOL
# 0 8 ORG EOL
# 15 2 ORG 322 10 ORG EOL
# 24 3 ORG 29 7 PERSON 45 10 ORG EOL
# EOL
# EOL
# 56 8 ORG EOL
# EOL
# EOL
# EOL
# 12 3 ORG 17 8 PERSON 28 3 ORG 33 13 PERSON 50 3 ORG 55 19 PERSON EOL
# EOL
# 76 6 PERSON 162 6 ORG EOL
# 57 2 ORG EOL
# 16 3 ORG 87 2 ORG EOL
# 8 7 PERSON 29 8 ORG 38 5 ORG 44 4 ORG EOL
# EOL
# 2 6 PERSON 28 3 ORG EOL
# 6 4 PERSON EOL
# 7 7 PERSON 111 9 PERSON EOL
# EOL
# 70 4 ORG 75 13 ORG EOL
# 27 8 ORG 101 7 ORG 121 3 ORG EOL
# EOL
# 21 5 ORG 77 6 PERSON EOL
# EOL
# EOL
# EOL
# 54 3 ORG 78 2 ORG EOL
# 90 8 ORG 99 5 ORG EOL
# 11 4 PERSON 16 7 PERSON 61 8 ORG EOL
# EOL
# 0 8 ORG EOL
# 82 5 ORG EOL
# EOL
# 47 8 PERSON 70 3 ORG EOL
# EOL
# EOL
# EOL
# 76 8 PERSON EOL
# 14 5 ORG EOL
# EOL
# 57 4 ORG 111 4 ORG 136 5 ORG EOL
# 133 6 PERSON EOL
# EOL
# 21 5 ORG 27 3 ORG 32 7 PERSON EOL
# EOL
# EOL
# EOL
# EOL
# 29 4 PERSON EOL
# 26 7 ORG 53 6 ORG EOL
# 40 9 PERSON 50 8 PERSON 181 9 ORG EOL
# 105 9 PERSON 116 9 PERSON 126 10 PERSON EOL
# 6 10 PERSON EOL
# 16 2 ORG 77 2 ORG 81 8 PERSON 159 3 ORG 164 11 PERSON 200 3 ORG EOL
# EOL
# 13 6 ORG EOL
# 68 11 ORG EOL
# 5 4 PERSON 91 4 PERSON EOL
# 127 3 ORG EOL
# EOL
# 21 7 PERSON 29 7 PERSON EOL
# 9 11 PERSON EOL
# 14 13 ORG 40 13 PERSON 84 7 PERSON 92 11 PERSON EOL
# 93 8 PERSON 103 9 PERSON EOL
# EOL
# EOL
# EOL
# 25 2 ORG EOL
# EOL
# EOL
# 5 10 PERSON 24 6 PERSON 79 3 ORG 127 2 PERSON 175 6 ORG EOL
# EOL
# EOL
# EOL
# 24 7 ORG EOL
# 2 6 PERSON EOL
# 10 9 PERSON EOL
# EOL
# EOL
# EOL
# 39 5 ORG 45 6 PERSON EOL
# 110 3 ORG 114 5 ORG EOL
# 95 8 ORG EOL
# 6 5 PERSON 44 5 PERSON 50 7 PERSON EOL
# EOL
# EOL
# 119 1 ORG 121 8 PERSON EOL
# EOL
# EOL
# EOL
# 8 5 PERSON EOL
# EOL
# EOL
# 0 2 ORG 47 6 ORG EOL
# 2 4 ORG 7 2 ORG EOL
# 21 10 PERSON 50 3 PERSON 54 6 PERSON EOL
# 33 3 ORG EOL
# EOL
# EOL
# 60 3 ORG 64 7 PERSON 72 4 PERSON EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# 56 2 ORG 59 4 PERSON 64 6 PERSON 71 8 PERSON 89 5 PERSON 111 7 PERSON 167 7 PERSON EOL
# EOL
# 51 11 PERSON 95 2 ORG 98 7 PERSON 106 8 PERSON EOL
# EOL
# EOL
# 3 10 ORG 14 7 ORG 40 8 ORG EOL
# EOL
# 189 8 ORG 200 3 ORG 206 3 ORG EOL
# EOL
# EOL
# EOL
# 40 3 ORG 135 3 ORG 160 5 PERSON EOL
# EOL
# 67 5 PERSON EOL
# 37 8 PERSON EOL
# 29 10 ORG 57 10 ORG EOL
# EOL
# 13 3 ORG 18 2 PERSON 21 4 PERSON EOL
# EOL
# 26 5 PERSON EOL
# 68 9 PERSON 131 4 ORG EOL
# EOL
# EOL
# 44 2 ORG 108 6 PERSON EOL
# 15 6 PERSON EOL
# EOL
# EOL
# 30 5 PERSON EOL
# EOL
# EOL
# 9 6 ORG 31 5 PERSON 99 5 ORG 204 5 ORG 277 4 ORG 312 7 ORG EOL
# EOL
# EOL
# 25 5 PERSON 32 5 PERSON EOL
# 27 4 ORG EOL
# 80 9 PERSON EOL
# 0 3 ORG 34 12 ORG 47 6 PERSON 54 11 PERSON EOL
# 26 6 PERSON 33 8 PERSON 67 6 PERSON 74 7 PERSON EOL
# EOL
# 47 9 PERSON 58 6 ORG EOL
# EOL
# EOL
# 185 3 ORG 189 5 PERSON 195 6 PERSON 203 4 ORG 208 5 ORG EOL
# EOL
# 13 6 PERSON EOL
# EOL
# 86 8 PERSON EOL
# EOL
# EOL
# 50 7 PERSON 73 3 ORG 77 7 PERSON EOL
# 92 3 ORG 96 2 PERSON 99 8 PERSON 110 3 ORG EOL
# EOL
# 15 8 ORG EOL
# EOL
# EOL
# 136 4 ORG EOL
# 110 6 ORG 117 6 PERSON 163 8 ORG EOL
# EOL
# 99 9 PERSON 162 2 ORG EOL
# 15 8 PERSON 24 5 PERSON 112 6 PERSON 119 6 PERSON EOL
# EOL
# EOL
# EOL
# EOL
# 36 5 PERSON 43 5 PERSON 50 5 ORG EOL
# EOL
# 11 6 ORG 18 3 ORG EOL
# 10 8 ORG EOL
# 37 9 PERSON EOL
# EOL
# 59 7 PERSON 67 8 PERSON 76 8 PERSON EOL
# EOL
# 11 9 PERSON 21 6 ORG 28 3 ORG EOL
# EOL
# EOL
# 10 7 ORG 60 12 ORG 97 2 ORG EOL
# EOL
# 79 6 PERSON EOL
# EOL
# 75 4 ORG EOL
# EOL
# 11 7 ORG EOL
# EOL
# EOL
# 49 8 PERSON 109 12 PERSON EOL
# 13 6 PERSON EOL
# EOL
# EOL
# EOL
# 113 7 PERSON 131 8 PERSON 140 11 PERSON EOL
# EOL
# 39 3 ORG EOL
# EOL
# 76 12 PERSON 90 10 PERSON 101 5 PERSON 116 8 PERSON EOL
# 13 5 PERSON 20 5 PERSON EOL
# EOL
# 24 4 ORG EOL
# EOL
# 8 8 PERSON EOL
# EOL
# 75 8 ORG 93 8 PERSON EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# 47 3 ORG EOL
# 2 13 PERSON EOL
# EOL
# EOL
# 30 6 ORG 83 18 ORG 118 8 PERSON EOL
# EOL
# 6 12 PERSON 76 6 ORG 123 3 ORG EOL
# 61 6 PERSON EOL
# EOL
# 27 8 PERSON 37 6 ORG 44 9 ORG 62 5 PERSON 68 6 PERSON EOL
# 28 11 ORG EOL
# EOL
# 123 5 ORG 130 3 ORG 134 8 ORG 143 8 ORG 152 2 ORG 155 8 ORG 164 6 ORG 171 5 ORG EOL
# EOL
# 45 3 ORG 167 3 ORG 173 6 ORG EOL
# 117 5 PERSON 133 8 PERSON EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# 13 5 ORG 82 6 ORG EOL
# EOL
# 62 5 PERSON EOL
# EOL
# 58 10 ORG 100 9 PERSON 111 7 ORG 132 6 PERSON 142 9 ORG EOL
# 6 8 PERSON EOL
# 160 10 PERSON EOL
# EOL
# 58 6 PERSON 66 8 ORG 75 8 ORG 84 6 ORG 117 12 PERSON 131 13 ORG 204 7 PERSON EOL
# 32 5 ORG 38 4 ORG 82 9 PERSON EOL
# 39 10 ORG 50 14 ORG EOL
# 95 5 ORG EOL
# 7 8 PERSON 17 14 PERSON 42 6 PERSON 49 7 PERSON 58 5 PERSON 64 7 PERSON 82 6 PERSON 210 2 ORG EOL
# 71 3 ORG EOL
# 144 9 ORG 154 12 ORG EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# 10 5 PERSON 16 10 PERSON 38 8 ORG 48 5 PERSON 54 8 ORG 86 8 ORG EOL
# 93 11 PERSON EOL
# 67 11 ORG EOL
# 77 6 PERSON EOL
# 87 6 PERSON 133 6 PERSON EOL
# EOL
# 107 9 PERSON 133 10 ORG 144 8 ORG 170 7 PERSON EOL
# EOL
# EOL
# 34 6 ORG 43 2 ORG 46 6 PERSON 53 8 PERSON 121 8 PERSON EOL
# EOL
# EOL
# EOL
# EOL
# 74 11 ORG EOL
# EOL
# EOL
# EOL
# 87 6 PERSON 94 2 ORG 135 13 ORG 166 6 PERSON 174 4 ORG EOL
# EOL
# 32 4 ORG EOL
# 27 9 PERSON 47 16 ORG 73 11 ORG 119 2 ORG EOL
# 13 9 ORG 23 17 ORG 76 3 ORG 81 3 ORG EOL
# 60 7 ORG 116 5 PERSON 122 8 PERSON EOL
# 6 4 PERSON EOL
# 92 3 ORG EOL
# EOL
# EOL
# 57 2 ORG 62 3 ORG 73 3 ORG 107 6 ORG 114 10 ORG 128 6 PERSON EOL
# EOL
# EOL
# EOL
# 62 7 PERSON EOL
# EOL
# EOL
# 12 15 PERSON 28 2 ORG EOL
# EOL
# 79 7 ORG EOL
# EOL
# EOL
# 42 13 ORG 90 6 PERSON EOL
# 80 7 PERSON 96 9 PERSON EOL
# EOL
# 35 3 ORG 40 4 PERSON 45 3 ORG 188 3 ORG EOL
# 33 8 ORG EOL
# 11 7 PERSON EOL
# EOL
# 15 9 PERSON EOL
# EOL
# 2 6 PERSON EOL
# 3 10 PERSON EOL
# EOL
# EOL
# 10 5 PERSON 16 8 PERSON EOL
# EOL
# EOL
# 54 6 ORG 68 6 ORG 75 3 ORG EOL
# EOL
# 110 9 ORG 132 8 ORG EOL
# 68 6 PERSON 94 8 PERSON 103 5 PERSON 119 9 PERSON EOL
# 0 6 ORG 42 4 PERSON EOL
# EOL
# 36 5 PERSON EOL
# 19 6 PERSON EOL
# EOL
# EOL
# 44 9 PERSON EOL
# EOL
# 9 4 PERSON 15 8 PERSON EOL
# EOL
# EOL
# 95 3 ORG EOL
# 61 8 PERSON EOL
# 7 4 PERSON EOL
# EOL
# 97 6 PERSON 104 7 PERSON EOL
# 143 9 ORG 153 5 ORG EOL
# EOL
# 86 4 PERSON 91 7 PERSON 335 10 ORG 390 7 PERSON EOL
# EOL
# EOL
# 40 6 PERSON EOL
# EOL
# 7 2 ORG 40 3 ORG EOL
# 86 8 ORG 114 10 PERSON 133 10 ORG 180 9 PERSON 190 6 PERSON EOL
# EOL
# EOL
# EOL
# 62 4 ORG EOL
# 12 11 ORG 80 10 ORG 101 3 ORG 168 8 ORG 177 8 ORG EOL
# 99 5 PERSON EOL
# EOL
# 9 7 PERSON 17 4 PERSON 93 5 PERSON EOL
# 127 3 ORG EOL
# EOL
# 139 1 ORG 142 10 PERSON 183 9 PERSON 193 2 ORG 219 1 ORG 221 1 ORG 224 8 PERSON 350 12 ORG 452 3 ORG 457 2 ORG 461 8 PERSON 472 3 ORG 477 7 ORG 487 3 ORG 492 3 ORG 497 10 ORG EOL
# EOL
# 23 2 ORG EOL
# EOL
# 87 7 PERSON EOL
# 28 9 PERSON 110 5 ORG 116 10 ORG 194 10 PERSON 239 10 PERSON EOL
# 32 9 PERSON EOL
# EOL
# 40 8 PERSON EOL
# 14 10 PERSON 25 9 PERSON 35 8 PERSON EOL
# 26 14 ORG 104 3 ORG 108 4 ORG 113 6 ORG 120 7 ORG 189 8 ORG EOL
# 9 10 PERSON 57 12 ORG 128 7 ORG EOL
# EOL
# EOL
# 76 5 ORG 128 6 ORG 161 3 ORG EOL
# EOL
# EOL
# 191 4 ORG 196 5 PERSON 202 8 PERSON 236 7 PERSON 244 10 PERSON 255 6 PERSON 262 7 PERSON EOL
# 57 1 ORG EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# 59 9 PERSON 98 8 PERSON 117 14 PERSON EOL
# 71 9 PERSON EOL
# EOL
# EOL
# 16 8 ORG EOL
# 84 2 ORG EOL
# EOL
# 10 6 PERSON 17 8 PERSON 27 7 PERSON EOL
# EOL
# EOL
# EOL
# EOL
# EOL
# 111 8 ORG EOL
# EOL
# EOL
# EOL

# %%
train_data = [["summer", 1924, 44],
              ["summer", 1932, 37],
              ["winter", 1980, 37],
              ["summer", 2012, 204]]

eval_data = [["winter", 1996, 197],
             ["winter", 1968, 37],
             ["summer", 2002, 77],
             ["summer", 1948, 59]]

cat_features = [0]

train_label = ["France", "USA", "USA", "UK"]
eval_label = ["USA", "France", "USA", "UK"]

# %%
train_dataset = Pool(data=train_data,
                     label=train_label,
                     cat_features=cat_features)

eval_dataset = Pool(data=eval_data,
                    label=eval_label,
                    cat_features=cat_features)

# Initialize CatBoostClassifier
model = CatBoostClassifier(iterations=10,
                           learning_rate=1,
                           depth=2,
                           loss_function='MultiClass')
# Fit model
model.fit(train_dataset)
# Get predicted classes
preds_class = model.predict(eval_dataset)
# Get predicted probabilities for each class
preds_proba = model.predict_proba(eval_dataset)
# Get predicted RawFormulaVal
preds_raw = model.predict(eval_dataset, 
                          prediction_type='RawFormulaVal')
# Out:
# 0:	learn: 0.9417331	total: 1.72ms	remaining: 15.5ms
# 1:	learn: 0.8421839	total: 4.04ms	remaining: 16.1ms
# 2:	learn: 0.6597822	total: 5.47ms	remaining: 12.8ms
# 3:	learn: 0.6028493	total: 7.99ms	remaining: 12ms
# 4:	learn: 0.4900112	total: 8.82ms	remaining: 8.82ms
# 5:	learn: 0.4076408	total: 10.7ms	remaining: 7.13ms
# 6:	learn: 0.3458205	total: 13.5ms	remaining: 5.8ms
# 7:	learn: 0.2982687	total: 15ms	remaining: 3.75ms
# 8:	learn: 0.2608927	total: 15.7ms	remaining: 1.75ms
# 9:	learn: 0.2309514	total: 17.1ms	remaining: 0us

# %%
preds_class
# Out:
# array([['USA'],
#        ['USA'],
#        ['UK'],
#        ['USA']], dtype='<U3')
